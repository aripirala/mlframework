# %%
import pandas as pd
import numpy as np
import os

# %%
# %cd /Users/aripiralasrinivas/Data Science/repos/mlframework/src
# Out:
# /Users/aripiralasrinivas/Data Science/repos/mlframework/src

# %%
WORKING_DIR = '/Users/aripiralasrinivas/Data Science/repos/mlframework'

# %%
file_path= os.path.join(WORKING_DIR, 'input')
file_path
# Out:
# '/Users/aripiralasrinivas/Data Science/repos/mlframework/input'

# %%
def get_file_path(fname=None):
    input_dir= os.path.join(WORKING_DIR, 'input')
    if fname is None:
        return input_dir
    else:
        return os.path.join(WORKING_DIR,'input', fname)

# %%
train_path= get_file_path('train.csv')
test_path = get_file_path('test.csv')
train_path
# Out:
# '/Users/aripiralasrinivas/Data Science/repos/mlframework/input/train.csv'

# %%
train_df = pd.read_csv(train_path)
test_df= pd.read_csv(test_path)

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train_df.columns[np.where(train_df.dtypes != np.float)[0]]
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces',
#        'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageCars', 'GarageArea',
# ...

# %%
series = train_df.MSSubClass
df = pd.DataFrame(series.value_counts()).reset_index()
type(df.iloc[:,1])
# Out:
# pandas.core.series.Series

# %%
from visualize import plot_cat_levels
plot_cat_levels(train_df.Exterior2nd)

# %%
train_df['GrLivArea'].hist()
# Out:
# <AxesSubplot:>

# %%
train_df.Exterior2nd.nunique()
# Out:
# 16

# %%
from utils import write_df, read_df

# write_df(train_constant_imputed, get_file_path('train_constant_imputed.csv'))

# %%
feature_dtypes_path = get_file_path('Feature_Analysis.csv') 
feature_dtypes_df = read_df(feature_dtypes_path)
feature_dtypes_df.head()
# Out:
# reading the dataframe: /Users/aripiralasrinivas/Data Science/repos/mlframework/input/Feature_Analysis.csv
#    Unnamed: 0               Name Feature_Type Sub_Type  \
# 0         NaN                 Id      Ignore       NaN
# 1         NaN           LotShape  Categorical      NaN
# 2         NaN       Neighborhood  Categorical      NaN
# 3         NaN        OverallQual  Categorical  Ordinal
# 4         NaN         'RoofMatl'  Categorical      NaN
#
#                      Possible treatments Possible treatments 2 Unnamed: 6  \
# 0                                    NaN                   NaN        NaN
# 1                                    NaN                   NaN        NaN
# 2      Reduce the number of categerories  Target mean encoding        NaN
# 3                   Target mean encoding                   NaN        NaN
# 4  Drop the feature as not much variance                   NaN        NaN
#
#   Unnamed: 7  Unnamed: 8
# 0        NaN         NaN
# 1        NaN         NaN
# ...

# %%
feature_dtypes_df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Feature_Type', 'Sub_Type', 'Possible treatments',
#        'Possible treatments 2', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %%
cols = ['Name', 'Feature_Type', 'Sub_Type', 'Possible treatments',
       'Possible treatments 2', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8']
feature_dtypes_df = feature_dtypes_df[cols]
feature_dtypes_df.head()
# Out:
#                 Name Feature_Type Sub_Type  \
# 0                 Id      Ignore       NaN
# 1           LotShape  Categorical      NaN
# 2       Neighborhood  Categorical      NaN
# 3        OverallQual  Categorical  Ordinal
# 4         'RoofMatl'  Categorical      NaN
#
#                      Possible treatments Possible treatments 2 Unnamed: 6  \
# 0                                    NaN                   NaN        NaN
# 1                                    NaN                   NaN        NaN
# 2      Reduce the number of categerories  Target mean encoding        NaN
# 3                   Target mean encoding                   NaN        NaN
# 4  Drop the feature as not much variance                   NaN        NaN
#
#   Unnamed: 7  Unnamed: 8
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN

# %%
cols_names = feature_dtypes_df[feature_dtypes_df.Feature_Type=='Categorical']['Name'].values
cols_names
# Out:
# array(['LotShape', 'Neighborhood', ' OverallQual', "       'RoofMatl'",
#        "       'ExterCond'", "'BsmtFinType1'", "       'BsmtHalfBath'",
#        "       'KitchenQual'", "       'FireplaceQu'",
#        "       'GarageQual'", "       'Fence'", "       'SaleCondition'",
#        " 'MSSubClass'", " 'LandContour'", "'Condition1'",
#        " 'OverallCond'", "'Exterior1st'", " 'Foundation'", " 'Heating'",
#        " 'FullBath'", " 'TotRmsAbvGrd'", " 'GarageType'", " 'GarageCond'",
#        "'3SsnPorch'", " 'MiscFeature'", " 'LotConfig'", " 'BldgType'",
#        " 'YearRemodAdd'", " 'MasVnrType'", " 'BsmtCond'", " 'CentralAir'",
#        " 'BedroomAbvGr'", " 'Fireplaces'", " 'GarageCars'", " 'MoSold'",
#        " 'MSZoning'", " 'Utilities'", "'Condition2'", " 'YearBuilt'",
#        "'Exterior2nd'", " 'BsmtQual'", "'BsmtFinType2'", " 'HeatingQC'",
#        " 'HalfBath'", " 'Functional'", " 'GarageFinish'", " 'PavedDrive'",
# ...

# %%
col = cols_names[0]
def clean_col_name(col):
#     print(col)
    col = col.strip()
    if "'" in col:
        col = col.split("'")[1]
    return col
clean_col_name(col)
# Out:
# LotShape
# 'LotShape'

# %%
clean_cols = [clean_col_name(col) for col in cols_names]
# Out:
# LotShape
# Neighborhood
#  OverallQual
#        'RoofMatl'
#        'ExterCond'
# 'BsmtFinType1'
#        'BsmtHalfBath'
#        'KitchenQual'
#        'FireplaceQu'
#        'GarageQual'
#        'Fence'
#        'SaleCondition'
#  'MSSubClass'
#  'LandContour'
# 'Condition1'
#  'OverallCond'
# 'Exterior1st'
#  'Foundation'
#  'Heating'
#  'FullBath'
#  'TotRmsAbvGrd'
#  'GarageType'
#  'GarageCond'
# '3SsnPorch'
#  'MiscFeature'
#  'LotConfig'
#  'BldgType'
#  'YearRemodAdd'
#  'MasVnrType'
#  'BsmtCond'
#  'CentralAir'
#  'BedroomAbvGr'
#  'Fireplaces'
#  'GarageCars'
#  'MoSold'
#  'MSZoning'
#  'Utilities'
# 'Condition2'
#  'YearBuilt'
# 'Exterior2nd'
#  'BsmtQual'
# 'BsmtFinType2'
#  'HeatingQC'
#  'HalfBath'
#  'Functional'
#  'GarageFinish'
#  'PavedDrive'
#  'Street'
#  'LandSlope'
#  'HouseStyle'
#  'RoofStyle'
#  'ExterQual'
#  'BsmtExposure'
#  'Electrical'
#  'BsmtFullBath'
#  'KitchenAbvGr'
#  'PoolQC'
#  'YrSold'
#  'Alley'
#  'SaleType'

# %%
clean_cols
# Out:
# ['LotShape',
#  'Neighborhood',
#  'OverallQual',
#  'RoofMatl',
#  'ExterCond',
#  'BsmtFinType1',
#  'BsmtHalfBath',
#  'KitchenQual',
#  'FireplaceQu',
#  'GarageQual',
#  'Fence',
#  'SaleCondition',
#  'MSSubClass',
#  'LandContour',
#  'Condition1',
#  'OverallCond',
#  'Exterior1st',
#  'Foundation',
#  'Heating',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'GarageType',
#  'GarageCond',
#  '3SsnPorch',
#  'MiscFeature',
#  'LotConfig',
#  'BldgType',
#  'YearRemodAdd',
#  'MasVnrType',
#  'BsmtCond',
#  'CentralAir',
#  'BedroomAbvGr',
#  'Fireplaces',
#  'GarageCars',
#  'MoSold',
#  'MSZoning',
#  'Utilities',
#  'Condition2',
#  'YearBuilt',
#  'Exterior2nd',
#  'BsmtQual',
#  'BsmtFinType2',
#  'HeatingQC',
#  'HalfBath',
#  'Functional',
#  'GarageFinish',
#  'PavedDrive',
#  'Street',
#  'LandSlope',
#  'HouseStyle',
#  'RoofStyle',
#  'ExterQual',
#  'BsmtExposure',
#  'Electrical',
#  'BsmtFullBath',
#  'KitchenAbvGr',
#  'PoolQC',
#  'YrSold',
#  'Alley',
#  'SaleType']

# %%
train_df[clean_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 60 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LotShape       1460 non-null   object
#  1   Neighborhood   1460 non-null   object
#  2   OverallQual    1460 non-null   int64
#  3   RoofMatl       1460 non-null   object
#  4   ExterCond      1460 non-null   object
#  5   BsmtFinType1   1423 non-null   object
#  6   BsmtHalfBath   1460 non-null   int64
#  7   KitchenQual    1460 non-null   object
#  8   FireplaceQu    770 non-null    object
#  9   GarageQual     1379 non-null   object
#  10  Fence          281 non-null    object
#  11  SaleCondition  1460 non-null   object
#  12  MSSubClass     1460 non-null   int64
#  13  LandContour    1460 non-null   object
#  14  Condition1     1460 non-null   object
#  15  OverallCond    1460 non-null   int64
#  16  Exterior1st    1460 non-null   object
# ...

# %%
numeric_cols = list(set(train_df.columns) - set(clean_cols))
train_df[numeric_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TotalBsmtSF    1460 non-null   int64
#  1   BsmtUnfSF      1460 non-null   int64
#  2   BsmtFinSF2     1460 non-null   int64
#  3   GarageYrBlt    1379 non-null   float64
#  4   MiscVal        1460 non-null   int64
#  5   EnclosedPorch  1460 non-null   int64
#  6   LotArea        1460 non-null   int64
#  7   SalePrice      1460 non-null   int64
#  8   LowQualFinSF   1460 non-null   int64
#  9   WoodDeckSF     1460 non-null   int64
#  10  ScreenPorch    1460 non-null   int64
#  11  MasVnrArea     1452 non-null   float64
#  12  LotFrontage    1201 non-null   float64
#  13  1stFlrSF       1460 non-null   int64
#  14  PoolArea       1460 non-null   int64
#  15  GrLivArea      1460 non-null   int64
#  16  OpenPorchSF    1460 non-null   int64
# ...

# %%
def convert_dtype(df, cols, dtype='float64'):
    df = df.copy(deep=True)
    for col in cols:
#         print(col)
        df[col] = df[col].astype(dtype)
    return df
train_dtype_treated = convert_dtype(train_df, numeric_cols, dtype='float64')
# Out:
# TotalBsmtSF
# BsmtUnfSF
# BsmtFinSF2
# GarageYrBlt
# MiscVal
# EnclosedPorch
# LotArea
# SalePrice
# LowQualFinSF
# WoodDeckSF
# ScreenPorch
# MasVnrArea
# LotFrontage
# 1stFlrSF
# PoolArea
# GrLivArea
# OpenPorchSF
# BsmtFinSF1
# GarageArea
# Id
# 2ndFlrSF

# %%
train_dtype_treated[numeric_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TotalBsmtSF    1460 non-null   float64
#  1   BsmtUnfSF      1460 non-null   float64
#  2   BsmtFinSF2     1460 non-null   float64
#  3   GarageYrBlt    1379 non-null   float64
#  4   MiscVal        1460 non-null   float64
#  5   EnclosedPorch  1460 non-null   float64
#  6   LotArea        1460 non-null   float64
#  7   SalePrice      1460 non-null   float64
#  8   LowQualFinSF   1460 non-null   float64
#  9   WoodDeckSF     1460 non-null   float64
#  10  ScreenPorch    1460 non-null   float64
#  11  MasVnrArea     1452 non-null   float64
#  12  LotFrontage    1201 non-null   float64
#  13  1stFlrSF       1460 non-null   float64
#  14  PoolArea       1460 non-null   float64
#  15  GrLivArea      1460 non-null   float64
#  16  OpenPorchSF    1460 non-null   float64
# ...

# %%
train_dtype_treated[clean_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 60 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LotShape       1460 non-null   object
#  1   Neighborhood   1460 non-null   object
#  2   OverallQual    1460 non-null   int64
#  3   RoofMatl       1460 non-null   object
#  4   ExterCond      1460 non-null   object
#  5   BsmtFinType1   1423 non-null   object
#  6   BsmtHalfBath   1460 non-null   int64
#  7   KitchenQual    1460 non-null   object
#  8   FireplaceQu    770 non-null    object
#  9   GarageQual     1379 non-null   object
#  10  Fence          281 non-null    object
#  11  SaleCondition  1460 non-null   object
#  12  MSSubClass     1460 non-null   int64
#  13  LandContour    1460 non-null   object
#  14  Condition1     1460 non-null   object
#  15  OverallCond    1460 non-null   int64
#  16  Exterior1st    1460 non-null   object
# ...

# %%
def t_normalize_dtype(source_df, target_df):
    """
    Change the target_df dtypes to same as source_df dataframes

    :param source_df: Pandas DataFrame. The dataframe to be used as reference.
    :param target_df: Pandas DataFrame. The dataframe that will be changed to same as source df
    :return: Pandas Dataframe. Which has the same datatypes as source_df
    """
    target_df = target_df.copy(deep=True)
    target_df = target_df.fillna(-99999)
    
    for col in target_df.columns:
        if col in source_df.columns:
            target_df[col] = target_df[col].astype(source_df[col].dtype)
    
    target_df = target_df.replace(to_replace=-99999, value=np.nan)
    
    return target_df

# %%
from utils import normalize_dtype
test_dtype_treated = t_normalize_dtype(train_dtype_treated, test_df)

# %%
col = 'BsmtFullBath'
dtype = train_dtype_treated[col].dtype
print(dtype)
from utils import missing_values_table
missing_values_table(test_df[[col]].fillna(np.nan))
# Out:
# int64
# Your selected dataframe has 1 columns.
# There are 1 columns that have missing values.
#               Missing Values  % of Total Values
# BsmtFullBath               2                0.1

# %%
missing_values_table(test_df)
# Out:
# Your selected dataframe has 81 columns.
# There are 33 columns that have missing values.
#               Missing Values  % of Total Values
# PoolQC                  1456               99.8
# MiscFeature             1408               96.5
# Alley                   1352               92.7
# Fence                   1169               80.1
# FireplaceQu              730               50.0
# LotFrontage              227               15.6
# GarageCond                78                5.3
# GarageYrBlt               78                5.3
# GarageQual                78                5.3
# GarageFinish              78                5.3
# GarageType                76                5.2
# BsmtCond                  45                3.1
# BsmtExposure              44                3.0
# BsmtQual                  44                3.0
# BsmtFinType1              42                2.9
# BsmtFinType2              42                2.9
# MasVnrType                16                1.1
# ...

# %%
missing_values_table(test_dtype_treated)
# Out:
# Your selected dataframe has 81 columns.
# There are 33 columns that have missing values.
#               Missing Values  % of Total Values
# PoolQC                  1456               99.8
# MiscFeature             1408               96.5
# Alley                   1352               92.7
# Fence                   1169               80.1
# FireplaceQu              730               50.0
# LotFrontage              227               15.6
# GarageCond                78                5.3
# GarageYrBlt               78                5.3
# GarageQual                78                5.3
# GarageFinish              78                5.3
# GarageType                76                5.2
# BsmtCond                  45                3.1
# BsmtExposure              44                3.0
# BsmtQual                  44                3.0
# BsmtFinType1              42                2.9
# BsmtFinType2              42                2.9
# MasVnrType                16                1.1
# ...

# %%
write_df(train_dtype_treated, get_file_path('train_dtype_treated.csv'))
write_df(test_dtype_treated, get_file_path('test_dtype_treated.csv'))
# Out:
# writing to the path: /Users/aripiralasrinivas/Data Science/repos/mlframework/input/train_dtype_treated.csv
# writing to the path: /Users/aripiralasrinivas/Data Science/repos/mlframework/input/test_dtype_treated.csv

# %%
test_dtype_treated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   float64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   float64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...
